# %%
#!/usr/bin/env python
#title           : yCRISPRv1.4.py
#description     : defines several methods to generate oligos for CRISPR
#author          : Leo d'Espaux <leodespaux@gmail.com>, help from Xingkai Li
#date            : 9 June 2015
#version         : 3.0
#notes           : includes options for 
#notes           : delGene replGene cutOligos
#notes           : at some point there will be one interface
#==============================================================================



# import libraries we're using
from Bio.Seq import Seq
from intermine.webservice import Service


def askUser():
    print("Hi baby, what are you in the mood for today? Using quotes enter")
    print("\"1\" to insert to an empty locus, \"2\" to edit an existing gene: ")
    print(" ")

    Action=input()
    if Action == "1":
        print(" ")
        print("Do you want to construct a cassette?")
        print("\"1\" to construct using standard promoter and terminator names, and a custom sequence")
        print("\"2\" to construct using standard promoter and terminator names, and a custom sequence")
        print(" ")

        typeEdit=input()
        if typeEdit=="1":
            print("Coming")
        inserttoEmpty(typeEdit)
    elif Action == "2":
        editExisting()
    
                # promt and ask to pick between these two options
                # 1 == "insert a gene into a new locus"
                # 2 == "edit exiting locus
                # and go to either of the next two functios
                 
def makeCassette():
    print("Coming soon.")

def inserttoEmpty(Sequence):
    print("Which of these characterized loci is going to get lucky: ")
    print(" ")
    print("208a, the first we used, defined as 100% ")    
    print("1021b, 105% ")
    print(" ")
    print("You know the drill, all answers in quotes.")
    
    filledLocus=input()
    
    # find locus info to primers
    # promt a table
        
    
    
def editExisting():
    print(" ")
    print("OK sweetie which locus do you want to edit, quotes and caps as in \"GPD1\": ")
    
    GeneName=input()
    
    service = Service("http://yeastmine.yeastgenome.org/yeastmine/service")
    template = service.get_template('Gene_GenomicDNA')

    rows = template.rows(
        E = {"op": "LOOKUP", "value": GeneName, "extra_value": "S. cerevisiae"}
    )
    
    # this service seems to return multiple similar genes but we want the first one only, so count
    count=0
    for row in rows:
        
        count=count+1
        if count==1:
            descr= row["description"]
            GeneSeq=Seq(row["sequence.residues"])
            print(" ")
            print("I think you want...... "+row["secondaryIdentifier"])
            print(row["description"])
            print(" ")
            print(row["sequence.residues"])
            print(" ")
            print("I have a feeling you're going to get lucky with this one... do you want to: ")
            print(" ")
            print("\"1\" just delete the gene, ASAP")
            print("\"2\" replace the old ORF with another ORF, or custom sequence")
            print("\"3\" it's complicated, replace a custom nearby sequence with another custom sequence")
            
            __init__(GeneName, GeneSeq, id=GeneName, name='<unknown name>', 
                     description='<unknown description>', dbxrefs=None, 
                     features=None, annotations=None, letter_annotations=None)
            
            oldGene=Seq(rpw["sequence.residues"])
            oldGene.id
            oldGeneName=
        upstream=findDNA(systematic name, gene, "up")
        downstream=findDNA()
        
        typeofEdit=input()
        if typeofEdit=="1":
            delGene(oldGene)
            # in deleteGene, update to look up the chromosome
    oldGeneIndex=findDNA(oldGene)
    

def findDNA(input):
    # this program loads on-machine chromosomal data from jun 2015 and finds a sequence within it
    # it returns
    # chromosomeNum, index, plus or minus
    # loading Chromosomes
    
    allRecords=[SeqIO.read("Yali0A_contig.fasta", "fasta"), SeqIO.read("Yali0B_contig.fasta", "fasta"),
        SeqIO.read("Yali0C_contig.fasta", "fasta"), SeqIO.read("Yali0D_contig.fasta", "fasta"),
        SeqIO.read("Yali0E_contig.fasta", "fasta"), SeqIO.read("Yali0F_contig.fasta", "fasta")]
        
       # for records in allRecords:
            # record.find(input)
            # return chromosome, id, direction. if direction is different,
            # return relative to the original ID, i.e., flip the chromosome view
            
     
    
    



def fetchGene(GeneName):
# Here we fetch genomic DNA using a name and return the sequence.
# If this works, you should see some text describing the gene as well.
    
    service = Service("http://yeastmine.yeastgenome.org/yeastmine/service")
    template = service.get_template('Gene_GenomicDNA')

    rows = template.rows(
        E = {"op": "LOOKUP", "value": GeneName, "extra_value": "S. cerevisiae"}
    )
    
    # this service seems to return multiple similar genes but we want the first one only, so count
    count=0
    for row in rows:
        
        count=count+1
        if count==1:
            descr= row["description"]
            old=Seq(row["sequence.residues"])
            print(" ")
            print("I think you want...... "+row["secondaryIdentifier"])
            print(row["description"])
            print(" ")

            return Seq(row["sequence.residues"])

    
    
def fetchHomology(GeneName, Direction):
    from intermine.webservice import Service
    service = Service("http://yeastmine.yeastgenome.org/yeastmine/service")

    # For a given gene(s), get a chosen length of upstream and/or downstream
    # sequence along with the gene sequence. Choose to retrieve 0.5 kb, 1.0 kb, or
    # 2.0 kb of upstream or downstream flanking regions, or both. To retrieve only
    # flanking regions without the coding sequence, select “false” for the “Gene
    # Flanking Region > Include Gene” option (for this option, you must select only
    # “upstream” or “downstream” flanking regions, not “both”).

    from intermine.webservice import Service
    service = Service("http://yeastmine.yeastgenome.org/yeastmine/service")

    # Retrieve the chromosomal location for a specified <a href =
    # "http://www.yeastgenome.org/yeastmine-help-page#gene">gene</a>.

    template = service.get_template('Gene_ChromosomeLocation')

    # You can edit the constraint values below
    # A    Gene

    rows = template.rows(
        A = {"op": "LOOKUP", "value": "act1"}
    )
    for row in rows:
        print row["primaryIdentifier"], row["secondaryIdentifier"], row["symbol"], row["name"], \
            row["organism.shortName"], row["chromosome.primaryIdentifier"], \
            row["chromosomeLocation.start"], row["chromosomeLocation.end"], \
            row["chromosomeLocation.strand"]
        
def stitchFragments(fragments):
    print("Working on it" )
    #fragments is an array
        
        
        
def cutOnly():
    
# This function asks user for a target cut site, and generates oligos to clone that cut site into 
# a CRISPR plasmid, and to screen for positive clones containing that cut site. It may also generate
# universal homology regions to integrate or otherwise alter that target region. 
#
# The current cut site architecture is:  >>>>> YtRNAp-HDV ribozyme- >20nt< -gRNA <<<<<

    
    GeneName=input("Name, using quotes: ")
    cutsite=input("20-mer cut sequence, using quotes: ")
    DNA=input("Locus sequence +/- a few kb, using quotes: ")

    if DNA.find(cutsite)==-1:                   # If cutiste sequence found in ANTISENSE
        DNA=Seq(DNA).reverse_complement()       # then reverse DNA, and turn it into a string
    
    index=DNA.find(cutsite)+16                  # index gives the start position of the string, e.g., 0. 
                                                # we add 16 since index+0=start of 20-mer, so index+16=cut site, 
                                                # 3 nt before last of 20mer
        
    Lup=DNA[index-520:index-490]                # This primer binds 500bp upstream of cut site

    
    cutSequence=Seq("cgggtggcgaatgggacttt")+cutsite+Seq("gttttagagctagaaatagc")
    seqprimer=Seq("gacttt")+cutsite
    

    print("cut" + GeneName + "  " + cutSequence)
    print("Lcolony" + GeneName + "  " + seqprimer)
    print("Lup" + GeneName + "  " + Lup)
  
    
    




def delGene(oldGene):

# This function asks user for a chromosomal locus, a region to be deleted, a suitable CRIPSR cutsite 
# and outputs oligos for cloning of a pL308 Cas9-gRNA vector, and ones for generating a donor DNA
# to delete the unwanted chromosomal region. Primers Lup+Rdown produce a 1kb band if deletion was
# successful. 
# part of yCRISPRv3 by leodespaux@gmail.com

    #
    #GeneName 

    deletion=oldGene

    print(" ")
    print("Ok I got you, do you want me to pick a cut site for you? ")
    print("\"1\" or enter your own cut site:")
    print(" ")
    cutChoice=input()
    if cutChoice=="1":
        cutsite=cutFinder(oldGene)
    else:
        cutsite=Seq(cutChoice)



    
    if deletion.find(cutsite)==-1:
        if deletion.reverse_complement().find(cutsite)==-1:
            print ("WARNING: Guide 20-mer sequence not found in deletion region.")
        
    locus=Seq(locus)
    
    index=locus.find(deletion)                  
    # index gives the start position within locus of the region to be deleted
    # note that it is
    
    newlocus=locus[0:index+1]+locus[index+len(deletion)-1:len(locus)]

    # note that since index starts at 0, a value of n points to, in the newlocus,
    # the first nt after the deletion. So we define the newlocus as above. Note too
    # that a string of len=40 ends at an index of 39--so we pick up at index+len-1. 
    
    Lup=newlocus[index-500:index-470]
    Rup=newlocus[index-31:index+29].reverse_complement()
    
    Ldown=newlocus[index-31:index+29]
    Rdown=newlocus[index+469:index+499].reverse_complement()
    
    cutSequence=Seq("cgggtggcgaatgggacttt")+cutsite+Seq("gttttagagctagaaatagc")
    seqprimer=Seq("gacttt")+cutsite
    
    print("cut" + GeneName + "  " + cutSequence)
    print("seq" + GeneName + "  " + seqprimer)
    print("Lup" + GeneName + "del" + " " + Lup)
    print("Rup" + GeneName + "del" + " " + Rup)
    print("Ldown" + GeneName + "del" + " " + Ldown)
    print("Rdown" + GeneName + "del" + " " + Rdown)

    
    




def insertGene():
    
# This function asks user for a target cut site, a target locus, and a DNA sequence to be inserted.
# The function outputs primers to allow one to PCR the insert with homology to the cut site. The final
# integration happens 17nt from the cut site in both direction, such that a 34nt region is deleted.
# The current cut site architecture is:  >>>>> YtRNAp-HDV ribozyme- >20nt< -gRNA <<<<<

    locusName=input("Locus name, using quotes: ")
    insertName=input("Name of gene to be inserted, using quotes: ")
    
    cutsite=input("20-mer cut sequence, using quotes: ").upper()
    locus=input("Locus sequence +/- a few kb, using quotes: ")
    insert=input("Enter insert DNA sequence, using quotes: ")


    if locus.find(cutsite)==-1:                   # If cutsite sequence found in ANTISENSE
        locus=Seq(locus).reverse_complement()     # then reverse DNA, and turn it into a string
    
    
    index=locus.find(cutsite)                     # index gives the start position of cutsite within locus
    
        
    Lprimer=locus[index-30:index]+insert[0:29]
    Rprimer=Seq(insert[len(insert)-29:len(insert)]+locus[index+34:index+64]).reverse_complement()
   
    Lhom=locus[index-60:index]
    Rhom=Seq(locus[index+34:index+94]).reverse_complement()
    
 
    print("L_" + insertName + "_:" + locusName + " " + Lprimer)
    print("R_" + insertName + "_:" + locusName + " " + Rprimer)
    print("Lext:" + locusName + " " + Lhom)
    print("Rext:" + locusName + " " + Rhom)

    
    



def replGene():
    
# This function asks user for a target cut site, a target locus, and a DNA sequence to be inserted.
# The function outputs primers to allow one to PCR the insert with homology to the cut site. The final
# integration happens 17nt from the cut site in both direction, such that a 34nt region is deleted.
# The current cut site architecture is:  >>>>> YtRNAp-HDV ribozyme- >20nt< -gRNA <<<<<

    locusName=input("Name of locus to be replaced, using quotes: ").lower()
    insertName=input("Name of gene to be inserted, using quotes: ").upper()
    cutsite=Seq(input("20-mer cut sequence, using quotes: ").upper())
    locus=Seq(input("Locus sequence +/- a few kb, using quotes: "))
    deletion=Seq(input("DNA sequence to be replaced, using quotes: "))
    insert=Seq(input("Enter insert DNA sequence, using quotes: "))


   # if locus.find(cutsite)==-1:                   # If cutsite sequence found in ANTISENSE
   #     locus=Seq(locus).reverse_complement()     # then reverse DNA, and turn it into a string
    
    index=locus.find(deletion)                     # index gives the start position of deletion
        
    # Let's define the locus resulting from the replacement  
    newlocus=locus[0:index]+insert+locus[index+len(deletion):len(locus)]
   
    # primers to PCR insert
    Lins= locus[index-30:index]+insert[0:30]
    Rins= (insert[len(insert)-30:len(insert)]+locus[index+len(deletion):index+len(deletion)+30]).reverse_complement() 
     
    # primers to PCR upstream homology region, ~500-bp
    Lup=newlocus[index-500:index-470]
    Rup=(locus[index-30:index]+insert[0:31]).reverse_complement() 
    
    # And primers to PCR downstream homology region
    Ldown=insert[len(insert)-30:len(insert)]+locus[index+len(deletion):index+len(deletion)+30]
    Rdown=(locus[index+len(deletion)+470:index+len(deletion)+500]).reverse_complement()
    
    cutSequence=Seq("cgggtggcgaatgggacttt")+cutsite+Seq("gttttagagctagaaatagc")
    seqprimer=Seq("gacttt")+cutsite
    
    print("cut" + locusName + "  " + cutSequence)
    print("seq" + locusName + "  " + seqprimer)
    print("Lins_" + locusName + "::"+insertName +" "+ Lins)
    print("Rins_" + locusName + "::"+insertName +" "+ Rins)
    print("Lup_" + locusName + " " + Lup)
    print("Rup_" + locusName + "::" + insertName +" " + Rup)
    print("Ldown_" + locusName + "::" + insertName +" " + Ldown)
    print("Rdown_" + locusName + " " + Rdown)
    
    
    
# to run, unhash your preferred program (and only that one) and ^Enter or play. E.g. remove hash below to run delGene()

#cutOnly()
#replGene()
#insertGene()
#delGene()


def DoTwo():
    a=input("Yo sup B :" )
    b=input("say what :" )
    return [a,b]

  
    
askUser()
# Out:
# Hi baby, what are you in the mood for today? Using quotes enter
# "1" to insert to an empty locus, "2" to edit an existing gene:
# "2"
#
# OK sweetie which locus do you want to edit, quotes and caps as in "GPD1":
# "TDH1"
#
# So we are choosing...... YJL052W
# Glyceraldehyde-3-phosphate dehydrogenase (GAPDH), isozyme 1; involved in glycolysis and gluconeogenesis; tetramer that catalyzes the reaction of glyceraldehyde-3-phosphate to 1,3 bis-phosphoglycerate; detected in the cytoplasm and cell wall; protein abundance increases in response to DNA replication stress; GAPDH-derived antimicrobial peptides secreted by S. cerevisiae are active against a wide variety of wine-related yeasts and bateria
#
# ...
#
# OK, I think you're going to get lucky with this one... do you want to:
#
# "1" just delete the gene, ASAP
# "2" replace the old ORF with another ORF, or custom sequence
# "3" it's complicated, replace a custom nearby sequence with another custom sequence
# "1"
#
# ...

# %%
input__init__(GeneName, GeneSeq, id=GeneName, name='<unknown name>', 
                     description='<unknown description>', dbxrefs=None, 
                     features=None, annotations=None, letter_annotations=None)
